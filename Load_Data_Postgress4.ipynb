# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import mysql.connector
from sqlalchemy import create_engine
import numpy as np
from os import walk
import psycopg2
import time
from config import db_password

# %%
df = pd.read_excel (r'Budget _Data.xlsx')

# %%
#def getDBengine():
user = 'postgres'
passw = db_password
host = 'policekillings.cv95lgysyvwq.us-east-1.rds.amazonaws.com'
port = 5432
database = 'PoliceKillings'
engine_1 = create_engine(f'postgres://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , pool_recycle=3600, echo=False)

# %%
dbConnection = engine_1.connect()

# %%
dataFrame = pd.DataFrame(df)

# %%
dataFrame
# Out:
#       Year of year State        City  Count of police_killings  \
# 0             2013    AK   Anchorage                        13
# 1             2013    AK   Fairbanks                         9
# 2             2013    AL  Birmingham                        18
# 3             2013    AL     Gadsden                         2
# 4             2013    AL      Mobile                         8
# ...            ...   ...         ...                       ...
# 1055          2017    DC  Charleston                         6
# 1056          2017    DC  Huntington                         2
# 1057          2017    DC    Wheeling                         1
# 1058          2017    DC      Casper                         7
# 1059          2017    DC    Cheyenne                         2
#
#       Police Buget Revised
# 0              454030000.0
# 1              292750000.0
# 2              421760000.0
# 3              263940000.0
# 4              230870000.0
# ...                    ...
# 1055           548010000.0
# 1056           274440000.0
# 1057           309330000.0
# 1058           276180000.0
# 1059           292550000.0
#
# [1060 rows x 5 columns]

# %%
try:
    frame = dataFrame.to_sql(name='City_Budget', con=engine_1, if_exists='replace',index=False);
except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)
