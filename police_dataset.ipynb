# %%
import warnings
warnings.filterwarnings('ignore')

# Matplotlib inline magic command
# %matplotlib inline

# %%
# Initial imports
import pandas as pd
from pandas.api.types import CategoricalDtype
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Scikit-Learn Model Selection and Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Scikit-Learn Model imports
from sklearn.linear_model import LinearRegression

# %%
# Sci-kit Learn Metrics imports
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Imbalanced Learn imports
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import EasyEnsembleClassifier
from imblearn.over_sampling import RandomOverSampler

# %%
# Load the data
file_path = 'dataset.xlsx' 
killings_df = pd.read_excel(file_path)                         
killings_df
# Out:
#      Victim's age Victim's gender Victim's race  \
# 0         Unknown            Male  Unknown race
# 1         Unknown            Male  Unknown race
# 2              61            Male  Unknown race
# 3              22            Male  Unknown race
# 4              33            Male  Unknown race
# ...           ...             ...           ...
# 8422           21            Male      Hispanic
# 8423           26            Male      Hispanic
# 8424           31            Male         Black
# 8425           49            Male      Hispanic
# 8426           26            Male         White
#
#      Date of Incident (month/day/year)               County  \
# 0                  2020-06-09 00:00:00  Virginia Beach City
# 1                  2020-05-09 00:00:00                 Cook
# 2                  2020-05-09 00:00:00                Bexar
# 3                  2020-05-09 00:00:00              Calhoun
# 4                  2020-04-09 00:00:00             Onondaga
# ...

# %%
#drop null values

# %%
#NLP (leave this for later, we will do this together with Joey)

# %%
#killings_df['year'] = killings_df['Date of Incident (month/day/year)'].dt.year
#get this to work (figure out why this isn't converting) (month, day, year, holiday)

# %%
# Use get_dummies() to transform text values into numerical values
killings_encoded = pd.get_dummies(killings_df, columns = ["Victim's gender", "Geography", "Body Camera (Source: WaPo)", "Fleeing (Source: WaPo)",
                                                         "Alleged Threat Level (Source: WaPo)", "Unarmed/Did Not Have an Actual Weapon", "Symptoms of mental illness?",
                                                         "Cause of death"])
killings_encoded.head()
# Out:
#   Victim's age Victim's race Date of Incident (month/day/year)  \
# 0      Unknown  Unknown race               2020-06-09 00:00:00
# 1      Unknown  Unknown race               2020-05-09 00:00:00
# 2           61  Unknown race               2020-05-09 00:00:00
# 3           22  Unknown race               2020-05-09 00:00:00
# 4           33  Unknown race               2020-04-09 00:00:00
#
#                 County                       Agency responsible for death  \
# 0  Virginia Beach City                   Virginia Beach Police Department
# 1                 Cook                          Chicago Police Department
# 2                Bexar                      San Antonio Police Department
# 3              Calhoun  Battle Creek Police Department, Calhoun County...
# 4             Onondaga                         Syracuse Police Department
#
#   A brief description of the circumstances surrounding the death  \
# 0  Police were called at 4:26 a.m. for a domestic...
# ...

# %%
#drop the columns that we need to drop
killings_encoded = killings_encoded.drop(["Victim's gender_Male", "Victim's gender_Unknown", "Victim's gender_Transgender", "Cause of death_Physical restraint", "Cause of death_Tasered"],axis=1)

# %%
#model code below 
#add below all this the model code from before
