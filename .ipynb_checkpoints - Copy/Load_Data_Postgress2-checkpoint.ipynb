# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import mysql.connector
from sqlalchemy import create_engine
import numpy as np
from os import walk
import psycopg2
import time

# %%
df = pd.read_excel (r'dataset.xlsx')

# %%
df
# Out:
#      Victim_age Victim_gender   Victim_race                Date   \
# 0       Unknown          Male  Unknown race  2020-06-09 00:00:00
# 1       Unknown          Male  Unknown race  2020-05-09 00:00:00
# 2            61          Male  Unknown race  2020-05-09 00:00:00
# 3            22          Male  Unknown race  2020-05-09 00:00:00
# 4            33          Male  Unknown race  2020-04-09 00:00:00
# ...         ...           ...           ...                  ...
# 8422         21          Male      Hispanic  2013-01-01 00:00:00
# 8423         26          Male      Hispanic  2013-01-01 00:00:00
# 8424         31          Male         Black  2013-01-01 00:00:00
# 8425         49          Male      Hispanic  2013-01-01 00:00:00
# 8426         26          Male         White  2013-01-01 00:00:00
#
#                    County                           Agency_responsible_death  \
# 0     Virginia Beach City                   Virginia Beach Police Department
# 1                    Cook                          Chicago Police Department
# 2                   Bexar                      San Antonio Police Department
# 3                 Calhoun  Battle Creek Police Department, Calhoun County...
# 4                Onondaga                         Syracuse Police Department
# ...                   ...                                                ...
# 8422               Pueblo                           Pueblo Police Department
# 8423                 Kern                      Bakersfield Police Department
# 8424              Douglas                            Omaha Police Department
# 8425             San Juan                       Farmington Police Department
# 8426           Blue Earth                Mankato Department of Public Safety
#
#      Cause_death
# 0        Gunshot
# 1        Gunshot
# 2        Gunshot
# 3        Gunshot
# 4        Gunshot
# ...          ...
# 8422     Gunshot
# 8423     Gunshot
# 8424     Gunshot
# 8425     Gunshot
# 8426       Taser
#
# [8427 rows x 7 columns]

# %%
df.to_csv('dataset.csv' , index= False , header=True)

# %%
df_2 = pd.read_csv('dataset.csv')

# %%
df_2
# Out:
#      Victim_age Victim_gender   Victim_race                Date   \
# 0       Unknown          Male  Unknown race  2020-06-09 00:00:00
# 1       Unknown          Male  Unknown race  2020-05-09 00:00:00
# 2            61          Male  Unknown race  2020-05-09 00:00:00
# 3            22          Male  Unknown race  2020-05-09 00:00:00
# 4            33          Male  Unknown race  2020-04-09 00:00:00
# ...         ...           ...           ...                  ...
# 8422         21          Male      Hispanic  2013-01-01 00:00:00
# 8423         26          Male      Hispanic  2013-01-01 00:00:00
# 8424         31          Male         Black  2013-01-01 00:00:00
# 8425         49          Male      Hispanic  2013-01-01 00:00:00
# 8426         26          Male         White  2013-01-01 00:00:00
#
#                    County                           Agency_responsible_death  \
# 0     Virginia Beach City                   Virginia Beach Police Department
# 1                    Cook                          Chicago Police Department
# 2                   Bexar                      San Antonio Police Department
# 3                 Calhoun  Battle Creek Police Department, Calhoun County...
# 4                Onondaga                         Syracuse Police Department
# ...                   ...                                                ...
# 8422               Pueblo                           Pueblo Police Department
# 8423                 Kern                      Bakersfield Police Department
# 8424              Douglas                            Omaha Police Department
# 8425             San Juan                       Farmington Police Department
# 8426           Blue Earth                Mankato Department of Public Safety
#
#      Cause_death
# 0        Gunshot
# 1        Gunshot
# 2        Gunshot
# 3        Gunshot
# 4        Gunshot
# ...          ...
# 8422     Gunshot
# 8423     Gunshot
# 8424     Gunshot
# 8425     Gunshot
# 8426       Taser
#
# [8427 rows x 7 columns]

# %%
from config import db_password

# %%
#def getDBengine():
user = 'postgres'
passw = 'Finalproject10'
host = 'policekillings.cv95lgysyvwq.us-east-1.rds.amazonaws.com'
port = 5432
database = 'PoliceKillings'
engine_1 = create_engine(f'postgres://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , pool_recycle=3600, echo=False)

# %%
dbConnection = engine_1.connect()

# %%
import time

# %%
dataFrame = pd.DataFrame(df_2)

# %%
try:
    frame = dataFrame.to_sql(name='police_killings', con=engine_1, if_exists='replace',index=False);
except ValueError as vx:

    print(vx)

except Exception as ex:   

    print(ex)
