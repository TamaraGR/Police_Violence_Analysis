# %% [markdown]
# # Machine Learning Model Mockup

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Initial imports
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import matplotlib.pyplot as plt

# %%
# scikit-learn imports
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# scikit-learn metrics imports
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import plot_confusion_matrix

# %%
# Load the data
file_path = 'Resources/2013-2020_Killings_by_PD_Cleaned.csv' 
killings_df = pd.read_csv(file_path)                         
killings_df

# CSV in this code manually cleaned in Excel to save time
# Will need to use '2013-2020_Killings_by_PD.csv' in final code
# Cleaning this data will require for loops
# Out:
#               State                City                                PD  \
# 0        New Mexico         Albuquerque     Albuquerque Police Department
# 1        California             Anaheim         Anaheim Police Department
# 2            Alaska           Anchorage       Anchorage Police Department
# 3             Texas           Arlington       Arlington Police Department
# 4           Georgia             Atlanta         Atlanta Police Department
# ..              ...                 ...                               ...
# 97         Virginia      Virginia Beach  Virginia Beach Police Department
# 98           Kansas             Wichita         Wichita Police Department
# 99   North Carolina       Winston-Salem   Winston-Salem Police Department
# 100   United States  Big Cities Average                Big Cities Average
# 101   United States  Nationwide Average                Nationwide Average
#
#            ORI  Black People Killed by Police (1/1/2013-12/31/2020)  \
# 0    NM0010100                                                3.0
# 1    CA0300100                                                3.0
# 2    AK0010100                                                1.0
# 3    TX2200100                                                7.0
# 4    GAAPD0000                                               16.0
# ..         ...                                                ...
# 97   VA1280000                                                4.0
# 98   KS0870300                                                1.0
# 99   NC0340200                                                3.0
# 100        NaN                                              850.0
# 101        NaN                                             2190.0
#
#      Hispanic People Killed by Police (1/1/2013-12/31/2020)  \
# 0                                                 22.0
# 1                                                  8.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  NaN
# ..                                                 ...
# 97                                                 NaN
# 98                                                 3.0
# 99                                                 NaN
# 100                                              554.0
# 101                                             1509.0
#
#      Native American People Killed by Police (1/1/2013-12/31/2020)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  3.0
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                               21.0
# 101                                              121.0
#
#      Asian People Killed by Police (1/1/2013-12/31/2020)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  2.0
# 4                                                  NaN
# ..                                                 ...
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                               51.0
# 101                                              132.0
#
#      Pacific Islanders Killed by Police (1/1/2013-12/31/2020)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  1.0
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                               19.0
# 101                                               49.0
#
#      White People Killed by Police (1/1/2013-12/31/2020)  ...  \
# 0                                                 12.0    ...
# 1                                                  3.0    ...
# 2                                                  6.0    ...
# 3                                                  3.0    ...
# 4                                                  1.0    ...
# ..                                                 ...    ...
# 97                                                 2.0    ...
# 98                                                11.0    ...
# 99                                                 NaN    ...
# 100                                              586.0    ...
# 101                                             3803.0    ...
#
#      Violent Crime Rate  2013 Total Arrests (UCR Data)  2014 Total Arrests  \
# 0                  11.2                        27700.0             25447.0
# 1                   3.4                         7891.0              8137.0
# 2                  10.9                        17601.0             14748.0
# 3                   5.0                        17258.0             16222.0
# 4                   9.8                        30505.0             26958.0
# ..                  ...                            ...                 ...
# 97                  1.4                        24319.0             23199.0
# 98                 10.3                        10566.0              9322.0
# 99                  6.4                        19744.0             18875.0
# 100                 7.2                      2440564.0           2285601.0
# 101                 NaN                            NaN                 NaN
#
#      2015 Total Arrests  2016 Total Arrests  2017 Total Arrests  \
# 0               22126.0             20341.0             21134.0
# 1                8381.0              9415.0              8869.0
# 2               14387.0             13294.0             13871.0
# 3               13999.0             11024.0              8354.0
# 4               24601.0             22161.0             22581.0
# ..                  ...                 ...                 ...
# 97              20188.0             19139.0             18603.0
# 98               9307.0              9120.0              8322.0
# 99              16792.0             15432.0                 NaN
# 100           2144017.0           2007193.0           1908113.0
# 101                 NaN                 NaN                 NaN
#
#     2018 Total Arrests 2019 Total Arrests  \
# 0              22247.0            22118.0
# 1              10019.0             9645.0
# 2              13973.0            13655.0
# 3               9552.0            10319.0
# 4                  NaN                NaN
# ..                 ...                ...
# 97             17133.0            17082.0
# 98              3937.0             9507.0
# 99             12786.0                NaN
# 100          1880088.0          1562378.0
# 101                NaN                NaN
#
#     Estimated Average Arrests per Year 2013-2019  \
# 0                                        22236.0
# 1                                         9078.0
# 2                                        13988.0
# 3                                        11578.0
# 4                                        24075.0
# ..                                           ...
# 97                                       19224.0
# 98                                        8253.0
# 99                                       15971.0
# 100                                      20840.0
# 101                                          NaN
#
#     Killings by Police per 10k Arrests
# 0                                 17.1
# 1                                 15.4
# 2                                 11.4
# 3                                 11.2
# 4                                  7.5
# ..                                 ...
# 97                                 4.2
# 98                                18.2
# 99                                 1.9
# 100                                NaN
# 101                                NaN
#
# [102 rows x 51 columns]

# %% [markdown]
# ## Preprocess Data

# %%
# Rename DataFrame columns
killings_df.columns = ['State', 'City', 'PD', 'ORI', 'Black_Killed, Hispanic_Killed', 'Native_Am_Killed', 
                       'Asian_Killed', 'Pacific_Islander_Killed', 'White_Killed', 'Unknown_Race_Killed', 
                       'All_Killed', 'Allegedly_Armed_Killed', 'Unarmed_Killed', 'Unclear_Armed_Status_Killed',
                       'Armed_with_Vehicle_Killed', 'Total_Population', 'Total_Black', 'Total_White',
                       'Total_Native_Am', 'Total_Asian', 'Total_Hawaiian', 'Total_Asian_Pac_Isl', 'Other',
                       'Two_Or', 'Total_Hispanic', 'Black_White_Dissimilarity_Index(2010)',
                       'Avg_Annual_Police_Homicide', 'Avg_Annual_Police_Homicide_Black', 
                       'Avg_Annual_Police_Homicide_White', 'Avg_Annual_Police_Homicide_Hispanic', 
                       'Black_White_Disparity', 'Hispanic_White_Disparity', 'Violent_Crimes_2013',
                       'Violent_Crimes_2014', 'Violent_Crimes_2015', 'Violent_Crimes_2016', 'Violent_Crimes_2017',
                       'Violent_Crimes_2018', 'Violent_Crimes_2019', 'Average_Violent_Crimes_2013-2019',
                       'Violent_Crime_Rate', '2013_Total_Arrests', '2014_Total_Arrests', '2014_Total_Arrests',
                       '2015_Total_Arrests', '2016_Total_Arrests', '2017_Total_Arrests', '2018_Total_Arrests',
                       '2019_Total_Arrests', 'Est_Avg_Arrests_per_Year(2013-2019)', 
                       'Killings_by_Police_per_10k_Arrests'
                      ]
killings_df.head(5)
# Out:
#         State         City                             PD        ORI  \
# 0  New Mexico  Albuquerque  Albuquerque Police Department  NM0010100
# 1  California      Anaheim      Anaheim Police Department  CA0300100
# 2      Alaska    Anchorage    Anchorage Police Department  AK0010100
# 3       Texas    Arlington    Arlington Police Department  TX2200100
# 4     Georgia      Atlanta      Atlanta Police Department  GAAPD0000
#
#    Black_Killed, Hispanic_Killed  Native_Am_Killed  Asian_Killed  \
# 0                            3.0              22.0           NaN
# 1                            3.0               8.0           NaN
# 2                            1.0               1.0           3.0
# 3                            7.0               1.0           NaN
# 4                           16.0               NaN           NaN
#
#    Pacific_Islander_Killed  White_Killed  Unknown_Race_Killed  ...  \
# 0                      NaN           NaN                 12.0  ...
# 1                      NaN           NaN                  3.0  ...
# 2                      NaN           1.0                  6.0  ...
# 3                      2.0           NaN                  3.0  ...
# 4                      NaN           NaN                  1.0  ...
#
#    2013_Total_Arrests  2014_Total_Arrests  2014_Total_Arrests  \
# 0                11.2             27700.0             25447.0
# 1                 3.4              7891.0              8137.0
# 2                10.9             17601.0             14748.0
# 3                 5.0             17258.0             16222.0
# 4                 9.8             30505.0             26958.0
#
#    2015_Total_Arrests  2016_Total_Arrests  2017_Total_Arrests  \
# 0             22126.0             20341.0             21134.0
# 1              8381.0              9415.0              8869.0
# 2             14387.0             13294.0             13871.0
# 3             13999.0             11024.0              8354.0
# 4             24601.0             22161.0             22581.0
#
#   2018_Total_Arrests 2019_Total_Arrests Est_Avg_Arrests_per_Year(2013-2019)  \
# 0            22247.0            22118.0                             22236.0
# 1            10019.0             9645.0                              9078.0
# 2            13973.0            13655.0                             13988.0
# 3             9552.0            10319.0                             11578.0
# 4                NaN                NaN                             24075.0
#
#   Killings_by_Police_per_10k_Arrests
# 0                               17.1
# 1                               15.4
# 2                               11.4
# 3                               11.2
# 4                                7.5
#
# [5 rows x 51 columns]

# %%
# Get column data types
killings_df.dtypes
# Out:
# State                                     object
# City                                      object
# PD                                        object
# ORI                                       object
# Black_Killed, Hispanic_Killed            float64
# Native_Am_Killed                         float64
# Asian_Killed                             float64
# Pacific_Islander_Killed                  float64
# White_Killed                             float64
# Unknown_Race_Killed                      float64
# All_Killed                               float64
# Allegedly_Armed_Killed                     int64
# Unarmed_Killed                           float64
# Unclear_Armed_Status_Killed              float64
# Armed_with_Vehicle_Killed                float64
# Total_Population                         float64
# Total_Black                               object
# Total_White                               object
# Total_Native_Am                           object
# Total_Asian                               object
# Total_Hawaiian                            object
# Total_Asian_Pac_Isl                       object
# Other                                    float64
# Two_Or                                    object
# Total_Hispanic                            object
# Black_White_Dissimilarity_Index(2010)     object
# Avg_Annual_Police_Homicide               float64
# Avg_Annual_Police_Homicide_Black         float64
# Avg_Annual_Police_Homicide_White         float64
# Avg_Annual_Police_Homicide_Hispanic      float64
# Black_White_Disparity                    float64
# Hispanic_White_Disparity                 float64
# Violent_Crimes_2013                      float64
# Violent_Crimes_2014                      float64
# Violent_Crimes_2015                      float64
# Violent_Crimes_2016                      float64
# Violent_Crimes_2017                      float64
# Violent_Crimes_2018                      float64
# Violent_Crimes_2019                      float64
# Average_Violent_Crimes_2013-2019         float64
# Violent_Crime_Rate                       float64
# 2013_Total_Arrests                       float64
# 2014_Total_Arrests                       float64
# 2014_Total_Arrests                       float64
# 2015_Total_Arrests                       float64
# 2016_Total_Arrests                       float64
# 2017_Total_Arrests                       float64
# 2018_Total_Arrests                       float64
# 2019_Total_Arrests                       float64
# Est_Avg_Arrests_per_Year(2013-2019)      float64
# Killings_by_Police_per_10k_Arrests        object
# dtype: object

# %%
# Find null values
for column in killings_df.columns:
    print(f'Column {column} has {killings_df[column].isnull().sum()} null values')
# Out:
# Column State has 0 null values
# Column City has 0 null values
# Column PD has 0 null values
# Column ORI has 2 null values
# Column Black_Killed, Hispanic_Killed has 7 null values
# Column Native_Am_Killed has 27 null values
# Column Asian_Killed has 90 null values
# Column Pacific_Islander_Killed has 69 null values
# Column White_Killed has 92 null values
# Column Unknown_Race_Killed has 9 null values
# Column All_Killed has 44 null values
# Column Allegedly_Armed_Killed has 0 null values
# Column Unarmed_Killed has 3 null values
# Column Unclear_Armed_Status_Killed has 19 null values
# Column Armed_with_Vehicle_Killed has 46 null values
# Column Total_Population has 48 null values
# Column Total_Black has 0 null values
# Column Total_White has 0 null values
# Column Total_Native_Am has 0 null values
# Column Total_Asian has 1 null values
# Column Total_Hawaiian has 1 null values
# Column Total_Asian_Pac_Isl has 1 null values
# Column Other has 1 null values
# Column Two_Or has 1 null values
# Column Total_Hispanic has 1 null values
# Column Black_White_Dissimilarity_Index(2010) has 0 null values
# Column Avg_Annual_Police_Homicide has 2 null values
# Column Avg_Annual_Police_Homicide_Black has 0 null values
# Column Avg_Annual_Police_Homicide_White has 0 null values
# Column Avg_Annual_Police_Homicide_Hispanic has 0 null values
# Column Black_White_Disparity has 0 null values
# Column Hispanic_White_Disparity has 0 null values
# Column Violent_Crimes_2013 has 0 null values
# Column Violent_Crimes_2014 has 3 null values
# Column Violent_Crimes_2015 has 6 null values
# Column Violent_Crimes_2016 has 5 null values
# Column Violent_Crimes_2017 has 7 null values
# Column Violent_Crimes_2018 has 10 null values
# Column Violent_Crimes_2019 has 5 null values
# Column Average_Violent_Crimes_2013-2019 has 4 null values
# Column Violent_Crime_Rate has 1 null values
# Column 2013_Total_Arrests has 1 null values
# Column 2014_Total_Arrests has 2014_Total_Arrests    11
# 2014_Total_Arrests     9
# dtype: int64 null values
# Column 2014_Total_Arrests has 2014_Total_Arrests    11
# 2014_Total_Arrests     9
# dtype: int64 null values
# Column 2015_Total_Arrests has 6 null values
# Column 2016_Total_Arrests has 7 null values
# Column 2017_Total_Arrests has 7 null values
# Column 2018_Total_Arrests has 4 null values
# Column 2019_Total_Arrests has 13 null values
# Column Est_Avg_Arrests_per_Year(2013-2019) has 3 null values
# Column Killings_by_Police_per_10k_Arrests has 4 null values

# %%
# Replace object NaNs with 'unknown'

# %%
# Replace float64 NaNs with '0'

# %%
# Drop unnecessary columns
del killings_df['ORI']
killings_df.head()
# Out:
#         State         City                             PD  \
# 0  New Mexico  Albuquerque  Albuquerque Police Department
# 1  California      Anaheim      Anaheim Police Department
# 2      Alaska    Anchorage    Anchorage Police Department
# 3       Texas    Arlington    Arlington Police Department
# 4     Georgia      Atlanta      Atlanta Police Department
#
#    Black_Killed, Hispanic_Killed  Native_Am_Killed  Asian_Killed  \
# 0                            3.0              22.0           NaN
# 1                            3.0               8.0           NaN
# 2                            1.0               1.0           3.0
# 3                            7.0               1.0           NaN
# 4                           16.0               NaN           NaN
#
#    Pacific_Islander_Killed  White_Killed  Unknown_Race_Killed  All_Killed  \
# 0                      NaN           NaN                 12.0         1.0
# 1                      NaN           NaN                  3.0         NaN
# 2                      NaN           1.0                  6.0         4.0
# 3                      2.0           NaN                  3.0         NaN
# 4                      NaN           NaN                  1.0         1.0
#
#    ...  2013_Total_Arrests  2014_Total_Arrests  2014_Total_Arrests  \
# 0  ...                11.2             27700.0             25447.0
# 1  ...                 3.4              7891.0              8137.0
# 2  ...                10.9             17601.0             14748.0
# 3  ...                 5.0             17258.0             16222.0
# 4  ...                 9.8             30505.0             26958.0
#
#    2015_Total_Arrests  2016_Total_Arrests 2017_Total_Arrests  \
# 0             22126.0             20341.0            21134.0
# 1              8381.0              9415.0             8869.0
# 2             14387.0             13294.0            13871.0
# 3             13999.0             11024.0             8354.0
# 4             24601.0             22161.0            22581.0
#
#   2018_Total_Arrests 2019_Total_Arrests Est_Avg_Arrests_per_Year(2013-2019)  \
# 0            22247.0            22118.0                             22236.0
# 1            10019.0             9645.0                              9078.0
# 2            13973.0            13655.0                             13988.0
# 3             9552.0            10319.0                             11578.0
# 4                NaN                NaN                             24075.0
#
#   Killings_by_Police_per_10k_Arrests
# 0                               17.1
# 1                               15.4
# 2                               11.4
# 3                               11.2
# 4                                7.5
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Split Data into Training and Testing

# %%
# Create features
X = pd.get_dummies(killings_df.drop(columns = ['Total_Black']))

# Create target
y = pd.DataFrame(killings_df['Total_Black'])

# %%
# Calculate stats
X.describe()
# Out:
#        Black_Killed, Hispanic_Killed  Native_Am_Killed  Asian_Killed  \
# count                      95.000000         75.000000     12.000000
# mean                       40.947368         34.893333     13.583333
# std                       239.194409        184.043368     34.272858
# min                         1.000000          1.000000      1.000000
# 25%                         2.000000          1.000000      1.750000
# 50%                         5.000000          4.000000      2.000000
# 75%                        11.500000          9.500000      3.250000
# max                      2190.000000       1509.000000    121.000000
#
#        Pacific_Islander_Killed  White_Killed  Unknown_Race_Killed  All_Killed  \
# count                33.000000     10.000000            93.000000   58.000000
# mean                  7.090909      8.700000            53.494624   21.034483
# std                  24.031703     15.477941           397.663273  125.595699
# min                   1.000000      1.000000             1.000000    1.000000
# 25%                   1.000000      1.000000             2.000000    1.000000
# 50%                   1.000000      1.000000             4.000000    2.000000
# 75%                   2.000000      9.250000            10.000000    3.000000
# max                 132.000000     49.000000          3803.000000  952.000000
#
#        Allegedly_Armed_Killed  Unarmed_Killed  Unclear_Armed_Status_Killed  \
# count              102.000000       99.000000                    83.000000
# mean               129.274510       16.656566                     3.831325
# std                889.816937       17.442712                     3.708327
# min                  0.000000        2.000000                     1.000000
# 25%                  9.000000        7.000000                     1.500000
# 50%                 16.000000       10.000000                     3.000000
# 75%                 27.000000       20.000000                     5.000000
# max               8756.000000      103.000000                    21.000000
#
#        ...  Killings_by_Police_per_10k_Arrests_8.3  \
# count  ...                              102.000000
# mean   ...                                0.009804
# std    ...                                0.099015
# min    ...                                0.000000
# 25%    ...                                0.000000
# 50%    ...                                0.000000
# 75%    ...                                0.000000
# max    ...                                1.000000
#
#        Killings_by_Police_per_10k_Arrests_8.5  \
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Killings_by_Police_per_10k_Arrests_8.6  \
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Killings_by_Police_per_10k_Arrests_8.7  \
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Killings_by_Police_per_10k_Arrests_9  \
# count                            102.000000
# mean                               0.019608
# std                                0.139333
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        Killings_by_Police_per_10k_Arrests_9.2  \
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Killings_by_Police_per_10k_Arrests_9.5  \
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Killings_by_Police_per_10k_Arrests_9.6  \
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Killings_by_Police_per_10k_Arrests_9.7  \
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Killings_by_Police_per_10k_Arrests_9.8
# count                              102.000000
# mean                                 0.009804
# std                                  0.099015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
# [8 rows x 1161 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state = 1)

y_train.shape
# Out:
# (76, 1)

# %% [markdown]
# ## Oversampling

# %% [markdown]
# ### Naive Random Oversampling
